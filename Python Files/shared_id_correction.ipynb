# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'D:\DATA SCIENCE\Data Analysis Projects\01. GDAPC\Case Study 1.1 Cyclistics Restarted\Good Data Stamp\v4_ka_updated.csv')

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                   ride_id  rideable_type member_casual    ride_duration  \
# 0        56F5C3ED5178C131   classic_bike        member  0 days 00:23:11
# 1        70BDF49A30C8BFFC   classic_bike        casual  0 days 00:04:46
# 2        B7F1F63BD1AFF4E9   classic_bike        member  0 days 00:10:22
# 3        444DD0D82A50BA8C   classic_bike        casual  0 days 00:07:56
# 4        510C1C0AA564ADF0   classic_bike        casual  0 days 00:21:45
# ...                   ...            ...           ...              ...
# 4186393  D10276507FC2E40A  electric_bike        member  0 days 00:05:30
# 4186394  C8FBE8FBA3C157F1  electric_bike        casual  0 days 00:05:27
# 4186395  B14C678DEA55A583  electric_bike        member  0 days 00:02:42
# 4186396  86CB9E2042DD6E4F  electric_bike        member  0 days 00:00:13
# 4186397  3E73BF87F0F0325A  electric_bike        member  0 days 00:00:51
#
#                   started_at             ended_at  \
# 0        2024-01-01 00:01:01  2024-01-01 00:24:12
# ...

# %%
start_ids = [
    "1524189", "20129", "21322", "21366", "21371", "21393", "23114", "23187", 
    "23215", "24156", "514", "515", "517", "518", "519", "520", "523", "525", 
    "527", "528", "KA1503000074"
]

# %%
id_filt = df[df['start_station_id'].isin(start_ids)]

# %%
id_filt.groupby(["start_station_id","start_station_name"])['start_station_id'].value_counts().reset_index(name='count')
# Out:
#    start_station_id                                 start_station_name  count
# 0           1524189                              Lowell Ave & Armitage    137
# 1           1524189                          Lowell Ave & Armitage Ave    154
# 2             20129                               Ada St & 113th Place      1
# 3             20129                                  Ada St & 113th St     11
# 4             21322                                     Grace & Cicero     20
# 5             21322                              Grace St & Cicero Ave    229
# 6             21366                               Spaulding Ave & 16th      1
# 7             21366                            Spaulding Ave & 16th St     69
# 8             21371                              Kildare & Chicago Ave      6
# 9             21371                          Kildare Ave & Chicago Ave     51
# 10            21393                                Oketo Ave & Addison      1
# ...

# %%
id_filt
# Out:
#                   ride_id  rideable_type member_casual    ride_duration  \
# 2        B7F1F63BD1AFF4E9   classic_bike        member  0 days 00:10:22
# 488      D0E16308C6D62CFB   classic_bike        casual  0 days 00:10:59
# 728      4AF3CC368FDB4AF2  electric_bike        casual  0 days 00:02:25
# 880      719763E6D4B90CA8   classic_bike        casual  0 days 00:45:46
# 1017     997C2CABD3C0DB16   classic_bike        member  0 days 00:19:24
# ...                   ...            ...           ...              ...
# 4186016  C14047AB0B33F9EB   classic_bike        member  0 days 00:06:10
# 4186094  7CEC9D5AB2DE39E7   classic_bike        casual  0 days 00:30:53
# 4186097  5964DB2ABD764DA8   classic_bike        casual  0 days 00:30:29
# 4186276  9C750E8F1087F498   classic_bike        casual  0 days 00:08:16
# 4186294  798FDE36DA2F1B3B  electric_bike        casual  0 days 00:11:23
#
#                   started_at             ended_at  \
# 2        2024-01-01 00:06:59  2024-01-01 00:17:21
# ...

# %%
end_ids = [
    "1524189", "20129", "21322", "21366", "21371", "21379", "23114", "23187",
    "23215", "24156", "24240", "514", "515", "517", "518", "519", "520", "523",
    "525", "527", "528", "530", "534", "535", "536", "537", "540", "543", "545",
    "546", "549", "553", "554", "556", "557", "559", "560", "561", "562", "564",
    "567", "569", "570", "571", "572", "573", "574", "576", "577", "579", "582",
    "583", "584", "585", "586", "587", "588", "590", "592", "593", "594", "595",
    "596", "599", "600", "604", "605", "620", "623", "624", "631", "632", "636",
    "637", "638", "639", "642", "643", "644", "646", "647", "649", "650", "651",
    "652", "KA1503000074"
]

# %%
end_id_filt = df[df['end_station_id'].isin(end_ids)]

# %%
pd.set_option('display.max_rows', None)

# %%
pd.reset_option('display.max_rows')

# %%
end_id_filt.groupby(["end_station_id", "end_station_name"])['end_station_id'].value_counts().reset_index(name="count")
# Out:
#     end_station_id                        end_station_name  count
# 0          1524189                   Lowell Ave & Armitage    156
# 1          1524189               Lowell Ave & Armitage Ave    148
# 2            20129                    Ada St & 113th Place      3
# 3            20129                       Ada St & 113th St     10
# 4            21322                          Grace & Cicero     14
# ..             ...                                     ...    ...
# 167            651                  Michigan Ave & 71st St    123
# 168            652                  Muskegon Ave & 89th St      2
# 169            652                    Rhodes Ave & 71st St     29
# 170   KA1503000074  Griffin Museum of Science and Industry   4234
# 171   KA1503000074          Museum of Science and Industry   1123
#
# [172 rows x 3 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
s_df =df

# %%
pd.reset_option('display.max_rows')

# %%
s_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4186398 entries, 0 to 4186397
# Data columns (total 14 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   member_casual       object
#  3   ride_duration       object
#  4   started_at          object
#  5   ended_at            object
#  6   start_station_name  object
#  7   start_station_id    object
#  8   end_station_name    object
#  9   end_station_id      object
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
# dtypes: float64(4), object(10)
# memory usage: 447.2+ MB

# %% [markdown]
# Map function to update start_station_name

# %%
station_map = {
    "528": "Pulaski Rd & Lake St",
    "20129": "Ada St & 113th St",
    "21322": "Grace St & Cicero Ave",
    "21366": "Spaulding Ave & 16th St",
    "21371": "Kildare Ave & Chicago Ave",
    "21379": "Rockwell St & Archer Ave",
    "21393": "Oketo Ave & Addison St",
    "23187": "Lockwood Ave & Grand Ave",
    "23215": "Lexington St & California Ave",
    "24240": "Kedzie Ave & 38th St",
    "1524189": "Lowell Ave & Armitage Ave",
    "KA1503000074": "Griffin Museum of Science and Industry"
}

# %%
station_id = [
    "528", "20129", "21322", "21366", "21371", "21379", "21393", 
    "23187", "23215", "24240", "1524189", "KA1503000074"
]

# %%
s_df['start_station_name'] = s_df['start_station_id'].map(station_map).combine_first(s_df['start_station_name'])

# %%
pd.set_option('display.max_rows', None)

# %%
verify_start = s_df[s_df['start_station_id'].isin(station_id)]

# %%
verify_start.groupby(['start_station_id', 'start_station_name'])['start_station_id'].value_counts()
# Out:
# start_station_id  start_station_name
# 1524189           Lowell Ave & Armitage Ave                  291
# 20129             Ada St & 113th St                           12
# 21322             Grace St & Cicero Ave                      249
# 21366             Spaulding Ave & 16th St                     70
# 21371             Kildare Ave & Chicago Ave                   57
# 21379             Rockwell St & Archer Ave                   296
# 21393             Oketo Ave & Addison St                      33
# 23187             Lockwood Ave & Grand Ave                   158
# 23215             Lexington St & California Ave              161
# 24240             Kedzie Ave & 38th St                        20
# 528               Pulaski Rd & Lake St                       111
# KA1503000074      Griffin Museum of Science and Industry    5395
# Name: count, dtype: int64
