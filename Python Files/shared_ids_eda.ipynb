# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'D:\DATA SCIENCE\Data Analysis Projects\01. GDAPC\Case Study 1.1 Cyclistics Restarted\Good Data Stamp\v2_no duplictae ride_id.csv')
shared = pd.read_csv(r'D:\DATA SCIENCE\Data Analysis Projects\01. GDAPC\Case Study 1.1 Cyclistics Restarted\Bad Data Extracted\shared_loc_ids.csv')

# %%
df = pd.DataFrame(data)
shared_df = pd.DataFrame(shared)

# %%
backup = df
shared_backup = shared_df

# %% [markdown]
# Shared IDs assorting

# %%
shared_df
# Out:
#                 ride_id  rideable_type member_casual    ride_duration  \
# 0      4AF3CC368FDB4AF2  electric_bike        casual  0 days 00:02:25
# 1      00F3D0275B07033D   classic_bike        member  0 days 00:00:01
# 2      F18280AE51FF8F06  electric_bike        member  0 days 01:12:55
# 3      2E74D9DCBCFA0E6F   classic_bike        casual  0 days 00:23:54
# 4      719763E6D4B90CA8   classic_bike        casual  0 days 00:45:46
# ...                 ...            ...           ...              ...
# 26879  63BEB732FCD6F07E   classic_bike        member  0 days 00:34:10
# 26880  7CEC9D5AB2DE39E7   classic_bike        casual  0 days 00:30:53
# 26881  5964DB2ABD764DA8   classic_bike        casual  0 days 00:30:29
# 26882  9C750E8F1087F498   classic_bike        casual  0 days 00:08:16
# 26883  D82FAF5544D34BE7   classic_bike        member  0 days 00:19:40
#
#                 started_at             ended_at  \
# 0      2024-01-01 09:40:18  2024-01-01 09:42:43
# ...

# %%
shared_df
# Out:
#                 ride_id  rideable_type member_casual    ride_duration  \
# 0      4AF3CC368FDB4AF2  electric_bike        casual  0 days 00:02:25
# 1      00F3D0275B07033D   classic_bike        member  0 days 00:00:01
# 2      F18280AE51FF8F06  electric_bike        member  0 days 01:12:55
# 3      2E74D9DCBCFA0E6F   classic_bike        casual  0 days 00:23:54
# 4      719763E6D4B90CA8   classic_bike        casual  0 days 00:45:46
# ...                 ...            ...           ...              ...
# 26879  63BEB732FCD6F07E   classic_bike        member  0 days 00:34:10
# 26880  7CEC9D5AB2DE39E7   classic_bike        casual  0 days 00:30:53
# 26881  5964DB2ABD764DA8   classic_bike        casual  0 days 00:30:29
# 26882  9C750E8F1087F498   classic_bike        casual  0 days 00:08:16
# 26883  D82FAF5544D34BE7   classic_bike        member  0 days 00:19:40
#
#                 started_at             ended_at  \
# 0      2024-01-01 09:40:18  2024-01-01 09:42:43
# ...

# %%
ids = shared_df.groupby(['start_station_id', 'end_station_id']).value_counts()

# %%
ids.head(10)
# Out:
# start_station_id  end_station_id  ride_id           rideable_type  member_casual  ride_duration    started_at           ended_at             start_station_name         end_station_name           start_lat  start_lng   end_lat    end_lng
# 1524189           1524189         105A8E19BD8B7035  classic_bike   member         0 days 00:00:58  2024-05-20 11:26:28  2024-05-20 11:27:26  Lowell Ave & Armitage      Lowell Ave & Armitage      41.917077  -87.735354  41.917077  -87.735354    1
#                                   13F54247EA264126  classic_bike   member         0 days 00:33:07  2024-05-14 10:36:18  2024-05-14 11:09:25  Lowell Ave & Armitage      Lowell Ave & Armitage      41.917077  -87.735354  41.917077  -87.735354    1
#                                   142AE50E3BFFA8DE  electric_bike  casual         0 days 00:26:29  2024-04-16 03:11:40  2024-04-16 03:38:09  Lowell Ave & Armitage      Lowell Ave & Armitage      41.916999  -87.735224  41.917030  -87.735026    1
# ...

# %%
ids = pd.DataFrame(ids)

# %%
ids.sort_values(by='start_station_id')
# Out:
#                                                                                                                                                                                                                                     count
# start_station_id end_station_id ride_id          rideable_type member_casual ride_duration   started_at          ended_at            start_station_name        end_station_name          start_lat start_lng  end_lat   end_lng
# 1524189          1524189        105A8E19BD8B7035 classic_bike  member        0 days 00:00:58 2024-05-20 11:26:28 2024-05-20 11:27:26 Lowell Ave & Armitage     Lowell Ave & Armitage     41.917077 -87.735354 41.917077 -87.735354      1
#                                 9C94DEC74081037E classic_bike  casual        0 days 01:18:41 2024-08-04 18:49:18 2024-08-04 20:07:59 Lowell Ave & Armitage     Lowell Ave & Armitage     41.917077 -87.735354 41.917077 -87.735354      1
# ...

# %%
shared_df[shared_df['start_station_id'] == '523']
# Out:
#                 ride_id  rideable_type member_casual    ride_duration  \
# 167    F203C78EF87C1BB6   classic_bike        member  0 days 00:03:58
# 210    019AB2C5F2870545   classic_bike        member  0 days 00:14:32
# 231    652BEB9AB82C0308   classic_bike        member  0 days 00:04:35
# 382    850020F3B2172522  electric_bike        member  0 days 00:07:47
# 728    D5DD2E0620146ACB   classic_bike        member  0 days 00:01:24
# ...                 ...            ...           ...              ...
# 26723  66D046B25C0F7043   classic_bike        member  0 days 00:19:16
# 26754  08D19DCD1C48EFF2   classic_bike        member  0 days 00:04:05
# 26765  1C545A1AF4C99A9D   classic_bike        member  0 days 00:16:00
# 26813  7FDD251B15428BF7   classic_bike        casual  0 days 00:17:18
# 26843  9136E16CA4C7BA64   classic_bike        member  0 days 00:17:26
#
#                 started_at             ended_at        start_station_name  \
# ...

# %%
df.nunique()
# Out:
# ride_id               4207975
# rideable_type               3
# member_casual               2
# ride_duration           20016
# started_at            3695056
# ended_at              3705634
# start_station_name       1789
# start_station_id         1744
# end_station_name         1799
# end_station_id           1750
# start_lat              429864
# start_lng              416558
# end_lat                  2332
# end_lng                  2333
# dtype: int64

# %%
public_rack = df[(df['start_station_name'].str.contains("public", case=False, na=False))
   | (df['end_station_name'].str.contains("public", case=False, na=False))]

# %%
public_rack.to_csv(r'D:\DATA SCIENCE\Data Analysis Projects\01. GDAPC\Case Study 1.1 Cyclistics Restarted\Bad Data Extracted\public_rack_data.csv', sep=',', index=False)

# %%
df['start_station_name'] = df['start_station_name'].str.replace(r'^Public Rack - ', '', regex=True)

# %%
df['end_station_name'] = df['end_station_name'].str.replace(r'^Public Rack - ', '', regex=True)

# %%
df[df['start_station_name'].str.contains("public rack - ", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, member_casual, ride_duration, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng]
# Index: []

# %%
df[df['end_station_name'].str.contains("public rack - ", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, member_casual, ride_duration, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng]
# Index: []

# %%
df.nunique()
# Out:
# ride_id               4207975
# rideable_type               3
# member_casual               2
# ride_duration           20016
# started_at            3695056
# ended_at              3705634
# start_station_name       1746
# start_station_id         1744
# end_station_name         1755
# end_station_id           1750
# start_lat              429864
# start_lng              416558
# end_lat                  2332
# end_lng                  2333
# dtype: int64

# %%
shared_df
# Out:
#                 ride_id  rideable_type member_casual    ride_duration  \
# 0      4AF3CC368FDB4AF2  electric_bike        casual  0 days 00:02:25
# 1      00F3D0275B07033D   classic_bike        member  0 days 00:00:01
# 2      F18280AE51FF8F06  electric_bike        member  0 days 01:12:55
# 3      2E74D9DCBCFA0E6F   classic_bike        casual  0 days 00:23:54
# 4      719763E6D4B90CA8   classic_bike        casual  0 days 00:45:46
# ...                 ...            ...           ...              ...
# 26879  63BEB732FCD6F07E   classic_bike        member  0 days 00:34:10
# 26880  7CEC9D5AB2DE39E7   classic_bike        casual  0 days 00:30:53
# 26881  5964DB2ABD764DA8   classic_bike        casual  0 days 00:30:29
# 26882  9C750E8F1087F498   classic_bike        casual  0 days 00:08:16
# 26883  D82FAF5544D34BE7   classic_bike        member  0 days 00:19:40
#
#                 started_at             ended_at  \
# 0      2024-01-01 09:40:18  2024-01-01 09:42:43
# ...

# %%
shared_df['end_station_name'] = df['end_station_name'].str.replace(r'^Public Rack - ', '', regex=True)
shared_df['start_station_name'] = df['start_station_name'].str.replace(r'^Public Rack - ', '', regex=True)

# %%
shared_df[shared_df['end_station_name'].str.contains("public rack - ", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, member_casual, ride_duration, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng]
# Index: []

# %%
shared_df[shared_df['start_station_name'].str.contains("public rack - ", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [ride_id, rideable_type, member_casual, ride_duration, started_at, ended_at, start_station_name, start_station_id, end_station_name, end_station_id, start_lat, start_lng, end_lat, end_lng]
# Index: []

# %%
shared_df.nunique()
# Out:
# ride_id               26884
# rideable_type             3
# member_casual             2
# ride_duration          5152
# started_at            26831
# ended_at              26858
# start_station_name      761
# start_station_id         90
# end_station_name        770
# end_station_id           95
# start_lat              3862
# start_lng              3900
# end_lat                 153
# end_lng                 153
# dtype: int64

# %%
start = df.groupby('start_station_id')['start_station_name'].nunique()

# %%
end = df.groupby('end_station_id')['end_station_name'].nunique()

# %%
end = end[end > 2]

# %%
start = start[start > 1]

# %%
start
# Out:
# start_station_id
# 1524189         2
# 20129           2
# 21322           2
# 21366           2
# 21371           2
#                ..
# 662             2
# 665             2
# KA1503000074    2
# KA17018054      2
# TA1305000030    2
# Name: start_station_name, Length: 91, dtype: int64

# %%
end
# Out:
# end_station_id
# Hubbard Bike-checking (LBS-WH-TEST)    3
# Name: end_station_name, dtype: int64

# %%
test_data = df[(df['end_station_id'].str.contains("test", case=False, na=False))
               |(df['start_station_id'].str.contains("test", case=False, na=False))]

# %%
test_data.to_csv(r'D:\DATA SCIENCE\Data Analysis Projects\01. GDAPC\Case Study 1.1 Cyclistics Restarted\Bad Data Extracted\testing_cycle_data.csv', sep=',', index=False)

# %%
test_data
# Out:
#                   ride_id     rideable_type member_casual    ride_duration  \
# 42239    8DF8F86F3569BB69      classic_bike        casual  0 days 21:59:22
# 80515    6C02F4E1C039CB0E      classic_bike        member  0 days 00:10:13
# 1340294  D48C58CD2712B17F      classic_bike        member  0 days 00:06:52
# 1355910  E62122E1876C0C0B      classic_bike        member  0 days 00:15:02
# 1725269  98AA7E7B4DEFD6A8     electric_bike        casual  0 days 00:04:55
# 1819934  DDC0210343E6F14C      classic_bike        casual  0 days 00:16:02
# 1837293  24D0B02930CFF8B6      classic_bike        casual  0 days 00:09:25
# 2064003  63B6AD06404EA474      classic_bike        casual  0 days 00:12:48
# 2072415  6E0D94D1B210AE7B     electric_bike        casual  0 days 00:12:33
# 2176664  24E4FE7614E33663      classic_bike        casual  0 days 00:11:46
# 2184790  307E35CCA2FEF7AD     electric_bike        casual  0 days 00:07:07
# ...

# %%
test_data.shape
# Out:
# (37, 14)

# %%
df[df['end_station_id'].str.contains("test", case=False, na=False)]

# %%
test = df

# %%
test = test[~test['end_station_id'].str.contains("test", case=False, na=False)]

# %%
df = test

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                   ride_id  rideable_type member_casual    ride_duration  \
# 0        56F5C3ED5178C131   classic_bike        member  0 days 00:23:11
# 1        70BDF49A30C8BFFC   classic_bike        casual  0 days 00:04:46
# 2        B7F1F63BD1AFF4E9   classic_bike        member  0 days 00:10:22
# 3        444DD0D82A50BA8C   classic_bike        casual  0 days 00:07:56
# 4        510C1C0AA564ADF0   classic_bike        casual  0 days 00:21:45
# ...                   ...            ...           ...              ...
# 4207933  D10276507FC2E40A  electric_bike        member  0 days 00:05:30
# 4207934  C8FBE8FBA3C157F1  electric_bike        casual  0 days 00:05:27
# 4207935  B14C678DEA55A583  electric_bike        member  0 days 00:02:42
# 4207936  86CB9E2042DD6E4F  electric_bike        member  0 days 00:00:13
# 4207937  3E73BF87F0F0325A  electric_bike        member  0 days 00:00:51
#
#                   started_at             ended_at  \
# 0        2024-01-01 00:01:01  2024-01-01 00:24:12
# ...

# %%
df.to_csv(r'D:\DATA SCIENCE\Data Analysis Projects\01. GDAPC\Case Study 1.1 Cyclistics Restarted\Good Data Stamp\v3_no_test_publicrack_data.csv', sep=',', index=False)

# %%
df.nunique()
# Out:
# ride_id               4207938
# rideable_type               3
# member_casual               2
# ride_duration           20015
# started_at            3695030
# ended_at              3705605
# start_station_name       1746
# start_station_id         1744
# end_station_name         1752
# end_station_id           1749
# start_lat              429863
# start_lng              416556
# end_lat                  2331
# end_lng                  2332
# dtype: int64

# %%
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'member_casual', 'ride_duration',
#        'started_at', 'ended_at', 'start_station_name', 'start_station_id',
#        'end_station_name', 'end_station_id', 'start_lat', 'start_lng',
#        'end_lat', 'end_lng'],
#       dtype='object')

# %%
# Count the number of unique start_station_name per start_station_id
station_name_counts = shared_id.groupby('start_station_id')['start_station_name'].nunique()

# Filter to get only those start_station_id where there is more than one variation in name
multiple_name_stations = station_name_counts[station_name_counts > 1]

# Display the station IDs with name variations
print(multiple_name_stations)
# Out:
# start_station_id
# 1524189         2
# 20129           2
# 21322           2
# 21366           2
# 21371           2
#                ..
# 662             2
# 665             2
# KA1503000074    2
# KA17018054      2
# TA1305000030    2
# Name: start_station_name, Length: 91, dtype: int64

# %%
# Get stations with multiple names
stations_with_variations = shared_id[shared_id['start_station_id'].isin(multiple_name_stations.index)]

# Sort for better visibility
stations_with_variations = stations_with_variations[['start_station_id', 'start_station_name']].drop_duplicates().sort_values('start_station_id')

print(stations_with_variations)
# Out:
#         start_station_id              start_station_name
# 513616           1524189           Lowell Ave & Armitage
# 2498353          1524189       Lowell Ave & Armitage Ave
# 3951016            20129            Ada St & 113th Place
# 370759             20129               Ada St & 113th St
# 681082             21322                  Grace & Cicero
# ...                  ...                             ...
# 886         KA1503000074  Museum of Science and Industry
# 496           KA17018054    Damen Ave & Walnut (Lake) St
# 2386011       KA17018054             Damen Ave & Lake St
# 79          TA1305000030          Clark St & Randolph St
# 84136       TA1305000030          Wells St & Randolph St
#
# [182 rows x 2 columns]

# %%
stations_with_variations.to_csv(r'D:\DATA SCIENCE\Data Analysis Projects\01. GDAPC\Case Study 1.1 Cyclistics Restarted\Bad Data Extracted\v1_start id.csv', sep=',', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4207938 entries, 0 to 4207937
# Data columns (total 14 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ride_id             object
#  1   rideable_type       object
#  2   member_casual       object
#  3   ride_duration       object
#  4   started_at          object
#  5   ended_at            object
#  6   start_station_name  object
#  7   start_station_id    object
#  8   end_station_name    object
#  9   end_station_id      object
#  10  start_lat           float64
#  11  start_lng           float64
#  12  end_lat             float64
#  13  end_lng             float64
# dtypes: float64(4), object(10)
# memory usage: 449.5+ MB

# %%
ta_id = df[(df['start_station_id'].str.contains("TA1305000030", case=False, na=False))
   | (df['end_station_id'].str.contains("TA1305000030", case=False, na=False))]

# %%
ta_id.to_csv(r'D:\DATA SCIENCE\Data Analysis Projects\01. GDAPC\Case Study 1.1 Cyclistics Restarted\Bad Data Extracted\ta_id_data.csv', sep=',', index=False)

# %%
ta_id = df[df['end_station_id'] != "TA1305000030"]

# %%
df = ta_id

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.to_csv(r'D:\DATA SCIENCE\Data Analysis Projects\01. GDAPC\Case Study 1.1 Cyclistics Restarted\Good Data Stamp\v3_no_test_publicrack_data.csv', sep=',', index=False)

# %%
KA17018054 = df[df['start_station_id'] == 'KA17018054']

# %%
KA17018054
# Out:
#                   ride_id  rideable_type member_casual    ride_duration  \
# 490      3F9A06ED3517F22D  electric_bike        member  0 days 00:14:56
# 4929     176DD38011BDE31C   classic_bike        member  0 days 00:42:37
# 6722     1A3A6CAF5F25AB77  electric_bike        casual  0 days 00:05:48
# 8962     43D6E4537766B0FB  electric_bike        casual  0 days 00:08:32
# 9070     5419273D9C4C503A  electric_bike        casual  0 days 00:09:12
# ...                   ...            ...           ...              ...
# 4178052  F959A957D7DDF21D  electric_bike        casual  0 days 00:06:02
# 4179519  65E1D89A180C8FA2  electric_bike        member  0 days 00:08:50
# 4182172  4B55939435D1E46F  electric_bike        casual  0 days 00:31:50
# 4182717  F38886424287C03C  electric_bike        member  0 days 00:04:04
# 4183254  6ED7B0895D312A3A   classic_bike        member  0 days 00:10:18
#
#                   started_at             ended_at  \
# 490      2024-01-01 02:45:29  2024-01-01 03:00:25
# ...

# %%
KA17018054['start_station_name'] = KA17018054['start_station_name'].str.replace("Damen Ave & Lake St", "Damen Ave & Walnut (Lake) St", regex=False)
# Out:
# C:\Users\username\AppData\Local\Temp\ipykernel_8224\2983748714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KA17018054['start_station_name'] = KA17018054['start_station_name'].str.replace("Damen Ave & Lake St", "Damen Ave & Walnut (Lake) St", regex=False)

# %%
KA17018054
# Out:
#                   ride_id  rideable_type member_casual    ride_duration  \
# 490      3F9A06ED3517F22D  electric_bike        member  0 days 00:14:56
# 4929     176DD38011BDE31C   classic_bike        member  0 days 00:42:37
# 6722     1A3A6CAF5F25AB77  electric_bike        casual  0 days 00:05:48
# 8962     43D6E4537766B0FB  electric_bike        casual  0 days 00:08:32
# 9070     5419273D9C4C503A  electric_bike        casual  0 days 00:09:12
# ...                   ...            ...           ...              ...
# 4178052  F959A957D7DDF21D  electric_bike        casual  0 days 00:06:02
# 4179519  65E1D89A180C8FA2  electric_bike        member  0 days 00:08:50
# 4182172  4B55939435D1E46F  electric_bike        casual  0 days 00:31:50
# 4182717  F38886424287C03C  electric_bike        member  0 days 00:04:04
# 4183254  6ED7B0895D312A3A   classic_bike        member  0 days 00:10:18
#
#                   started_at             ended_at  \
# 490      2024-01-01 02:45:29  2024-01-01 03:00:25
# ...

# %%
ka_df = df

# %%
ka_df[ka_df['end_station_id'] == "KA17018054"]
# Out:
#                   ride_id  rideable_type member_casual    ride_duration  \
# 2716     351055A3FBEFB6CB   classic_bike        member  0 days 00:04:15
# 2720     965D32A198A7F224  electric_bike        member  0 days 00:23:06
# 3329     393AB7AC6472520B  electric_bike        member  0 days 00:11:42
# 3861     14DD601D29662E50  electric_bike        member  0 days 00:02:58
# 6753     09BA4A45412B87A3  electric_bike        member  0 days 00:14:25
# ...                   ...            ...           ...              ...
# 4174215  0A0BFE542AEA1BF6  electric_bike        casual  0 days 00:14:56
# 4175210  C6AFDF2D16FADD23   classic_bike        member  0 days 00:14:23
# 4177166  11C7B9869D7593CB  electric_bike        casual  0 days 00:51:44
# 4180110  45876DE7C31C20FF  electric_bike        casual  0 days 00:02:43
# 4180538  9F13B06C29CD1A0A  electric_bike        member  0 days 00:03:44
#
#                   started_at             ended_at  \
# 2716     2024-01-02 05:23:08  2024-01-02 05:27:23
# ...

# %%
ka_df.loc[ka_df['start_station_id'].str.contains("KA17018054", na=False), 'start_station_name'] = "Damen Ave & Walnut (Lake) St"

# %%
ka_df.loc[ka_df['end_station_id'].str.contains("KA17018054", na=False), 'end_station_name'] = "Damen Ave & Walnut (Lake) St"

# %%
ka_df.nunique()
# Out:
# ride_id               4186398
# rideable_type               3
# member_casual               2
# ride_duration           19982
# started_at            3678433
# ended_at              3688935
# start_station_name       1743
# start_station_id         1743
# end_station_name         1749
# end_station_id           1748
# start_lat              428725
# start_lng              414905
# end_lat                  2326
# end_lng                  2327
# dtype: int64

# %% [markdown]
# KA1503000074
# UPDATED

# %%
ka_df.to_csv(r'D:\DATA SCIENCE\Data Analysis Projects\01. GDAPC\Case Study 1.1 Cyclistics Restarted\Good Data Stamp\v4_ka_updated.csv', sep=',', index=False)

# %% [markdown]
# Make duplicate df for

# %%
df.nunique()
# Out:
# ride_id               4186398
# rideable_type               3
# member_casual               2
# ride_duration           19982
# started_at            3678433
# ended_at              3688935
# start_station_name       1743
# start_station_id         1743
# end_station_name         1749
# end_station_id           1748
# start_lat              428725
# start_lng              414905
# end_lat                  2326
# end_lng                  2327
# dtype: int64

# %%
df[df['end_station_id'] == "1524189"]
# Out:
#                   ride_id  rideable_type member_casual    ride_duration  \
# 503858   A9EF393AA62939FE   classic_bike        member  0 days 00:10:25
# 510600   3E35D0B966575271  electric_bike        member  0 days 00:01:42
# 562756   912908966F3F85D7   classic_bike        member  0 days 00:15:11
# 564568   420A901B4259E380   classic_bike        member  0 days 00:26:25
# 570809   2BB3222CE6CF01D6  electric_bike        member  0 days 00:12:38
# ...                   ...            ...           ...              ...
# 4173662  FAD39E2442DD00DD  electric_bike        member  0 days 00:17:27
# 4176088  4375F673C72728CC   classic_bike        member  0 days 00:04:42
# 4179102  D61A722809B1E69D  electric_bike        member  0 days 00:20:39
# 4186094  7CEC9D5AB2DE39E7   classic_bike        casual  0 days 00:30:53
# 4186097  5964DB2ABD764DA8   classic_bike        casual  0 days 00:30:29
#
#                   started_at             ended_at  \
# 503858   2024-03-28 18:51:51  2024-03-28 19:02:16
# ...

# %%
df.groupby('start_station_id')['start_station_name'].nunique().reset_index().query('start_station_name > 1')
# Out:
#      start_station_id  start_station_name
# 375           1524189                   2
# 496             20129                   2
# 566             21322                   2
# 596             21366                   2
# 599             21371                   2
# ...               ...                 ...
# 1119              660                   2
# 1120              661                   2
# 1121              662                   2
# 1123              665                   2
# 1496     KA1503000074                   2
#
# [89 rows x 2 columns]

# %%
# !pip install fuzzywuzzy python-Levenshtein
from fuzzywuzzy import process, fuzz
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 667.9 kB/s eta 0:00:02
#    ------------- -------------------------- 0.5/1.6 MB 667.9 kB/s eta 0:00:02
#    ------------------- -------------------- 0.8/1.6 MB 780.6 kB/s eta 0:00:02
#    -------------------------- ------------- 1.0/1.6 MB 889.3 kB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 931.1 kB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 931.1 kB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 874.0 kB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# ...

# %%
import pandas as pd
from fuzzywuzzy import process, fuzz

# Group by start_station_id and collect unique names
station_groups = df.groupby('start_station_id')['start_station_name'].unique().reset_index()

# Check IDs with more than one unique name
station_groups['name_count'] = station_groups['start_station_name'].apply(len)
multiple_names = station_groups[station_groups['name_count'] > 1]

# Analyze name differences within each start_station_id
for index, row in multiple_names.iterrows():
    station_id = row['start_station_id']
    names = row['start_station_name']
    print(f"\n🚉 **Station ID:** {station_id}")
    
    # Compare names within the same station_id
    for name in names:
        matches = process.extract(name, names, limit=len(names), scorer=fuzz.token_sort_ratio)
        print(f"   Original: {name}")
# Out:
# 🚉 **Station ID:** 1524189
#    Original: Lowell Ave & Armitage
#    Original: Lowell Ave & Armitage Ave
#
# 🚉 **Station ID:** 20129
#    Original: Ada St & 113th St
#    Original: Ada St & 113th Place
#
# 🚉 **Station ID:** 21322
#    Original: Grace & Cicero
#    Original: Grace St & Cicero Ave
#
# 🚉 **Station ID:** 21366
#    Original: Spaulding Ave & 16th
#    Original: Spaulding Ave & 16th St
#
# 🚉 **Station ID:** 21371
#    Original: Kildare & Chicago Ave
#    Original: Kildare Ave & Chicago Ave
#
# 🚉 **Station ID:** 21379
#    Original: Rockwell St & Archer Ave\t
#    Original: Rockwell St & Archer Ave
#
# 🚉 **Station ID:** 21393
#    Original: Oketo Ave & Addison
#    Original: Oketo Ave & Addison St
#
# 🚉 **Station ID:** 23114
#    Original: Kildare Ave & 85th St
#    Original: Kildare Ave & 85th St (Kostner Ave & 87th St TEMPORARY)
#
# 🚉 **Station ID:** 23187
#    Original: Lockwood Ave and Grand Ave
#    Original: Lockwood Ave & Grand Ave
#
# 🚉 **Station ID:** 23215
# ...

# %%
import pandas as pd
from fuzzywuzzy import process, fuzz

# Group by start_station_id and collect unique names
station_groups = df.groupby('end_station_id')['end_station_name'].unique().reset_index()

# Check IDs with more than one unique name
station_groups['name_count'] = station_groups['end_station_name'].apply(len)
multiple_names = station_groups[station_groups['name_count'] > 1]

# Analyze name differences within each start_station_id
for index, row in multiple_names.iterrows():
    station_id = row['end_station_id']
    names = row['end_station_name']
    print(f"\n🚉 **Station ID:** {station_id}")
    
    # Compare names within the same station_id
    for name in names:
        matches = process.extract(name, names, limit=len(names), scorer=fuzz.token_sort_ratio)
        print(f"   Original: {name}")
# Out:
# 🚉 **Station ID:** 1524189
#    Original: Lowell Ave & Armitage
#    Original: Lowell Ave & Armitage Ave
#
# 🚉 **Station ID:** 20129
#    Original: Ada St & 113th St
#    Original: Ada St & 113th Place
#
# 🚉 **Station ID:** 21322
#    Original: Grace & Cicero
#    Original: Grace St & Cicero Ave
#
# 🚉 **Station ID:** 21366
#    Original: Spaulding Ave & 16th
#    Original: Spaulding Ave & 16th St
#
# 🚉 **Station ID:** 21371
#    Original: Kildare & Chicago Ave
#    Original: Kildare Ave & Chicago Ave
#
# 🚉 **Station ID:** 21379
#    Original: Rockwell St & Archer Ave\t
#    Original: Rockwell St & Archer Ave
#
# 🚉 **Station ID:** 23114
#    Original: Kildare Ave & 85th St
#    Original: Kildare Ave & 85th St (Kostner Ave & 87th St TEMPORARY)
#
# 🚉 **Station ID:** 23187
#    Original: Lockwood Ave and Grand Ave
#    Original: Lockwood Ave & Grand Ave
#
# 🚉 **Station ID:** 23215
#    Original: Lexington & California Ave
#    Original: Lexington St & California Ave
#
# ...
